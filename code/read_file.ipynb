# %%
#Jia Yi/Susan Wang

# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_json('data/genres.json.gz', orient='record', lines=True, encoding='utf-8')

# %%
data1
# Out:
#      wikidata_id         genre_label
# 0      Q43334491             novella
# 1      Q42304051           cityscape
# 2      Q39894018    drama with music
# 3      Q47909472           lunar art
# 4      Q42922249  Tsukuri monogatari
# ...          ...                 ...
# 5554   Q26228231     cyberpunk novel
# 5555   Q26268098             Eastern
# 5556   Q26965555        hunting deck
# 5557   Q22349373              Lirico
# 5558   Q22669429           engraving
#
# [5559 rows x 2 columns]

# %%
data2 = pd.read_json('data/omdb-data.json.gz', orient='record', lines=True, encoding='utf-8')

# %%
data2
# Out:
#         imdb_id                    omdb_genres  \
# 0     tt0060814          [Drama, History, War]
# 1     tt2379713  [Action, Adventure, Thriller]
# 2     tt0230575               [Comedy, Horror]
# 3     tt0065988     [Adventure, Comedy, Drama]
# 4     tt1995390       [Crime, Drama, Thriller]
# ...         ...                            ...
# 9671  tt0052365            [Action, Adventure]
# 9672  tt0088099       [Comedy, Drama, Romance]
# 9673  tt5580036     [Biography, Comedy, Drama]
# 9674  tt2244376                        [Drama]
# 9675  tt4986098             [Sci-Fi, Thriller]
#
#                                               omdb_plot  \
# 0     In this sprawling, star-laden film, we see the...
# 1     A cryptic message from the past sends James Bo...
# 2     The makers of this parody of "Night of the Liv...
# 3     Jack Crabb is 121 years old as the film begins...
# 4     When Perry and his girlfriend, Gail, cross pat...
# ...

# %%
data3 = pd.read_json('data/rotten-tomatoes.json.gz', orient='record', lines=True, encoding='utf-8')

# %%
data3
# Out:
#        audience_average  audience_percent  audience_ratings  critic_average  \
# 0                   3.9              86.0        33125227.0             7.1
# 1                   4.1              80.0            2139.0             7.8
# 2                   3.6              71.0           11482.0             7.6
# 3                   3.6              66.0          187204.0             6.6
# 4                   3.9              84.0           26836.0             7.4
# ...                 ...               ...               ...             ...
# 40225               3.6              69.0            2350.0             NaN
# 40226               4.3              70.0             118.0             NaN
# 40227               3.8              84.0             309.0             NaN
# 40228               2.9              53.0           14648.0             6.4
# 40229               NaN               NaN               0.0             NaN
#
#        critic_percent    imdb_id  \
# ...

# %%
data4 = pd.read_json('data/wikidata-movies.json.gz', orient='record', lines=True, encoding='utf-8')

# %%
data4
# Out:
#       wikidata_id                                      label    imdb_id  \
# 0       Q43079072                              If I Were You  tt1587309
# 1       Q43302269                 Krampus: The Devil Returns  tt3527772
# 2       Q43400054                                        NaN  tt6462462
# 3       Q43401863                         A Christmas Prince  tt7608418
# 4       Q41850450                             Pengabdi Setan  tt7076834
# ...           ...                                        ...        ...
# 40425   Q23838435  The Happiest Day in the Life of Olli Mäki  tt4771932
# 40426   Q23838477                         The Pistol Shrimps  tt5563100
# 40427   Q23848755                             The Banksy Job  tt4406572
# 40428   Q23899905                         In Jackson Heights  tt4936064
# 40429   Q23899915                              The McMasters  tt0064649
#
#                                      rotten_tomatoes_id  \
# ...

# %%
data2.explode('omdb_genres')
# Out:
#         imdb_id omdb_genres  \
# 0     tt0060814       Drama
# 0     tt0060814     History
# 0     tt0060814         War
# 1     tt2379713      Action
# 1     tt2379713   Adventure
# ...         ...         ...
# 9673  tt5580036      Comedy
# 9673  tt5580036       Drama
# 9674  tt2244376       Drama
# 9675  tt4986098      Sci-Fi
# 9675  tt4986098    Thriller
#
#                                               omdb_plot  \
# 0     In this sprawling, star-laden film, we see the...
# 0     In this sprawling, star-laden film, we see the...
# 0     In this sprawling, star-laden film, we see the...
# 1     A cryptic message from the past sends James Bo...
# 1     A cryptic message from the past sends James Bo...
# ...                                                 ...
# 9673  Competitive ice skater Tonya Harding rises amo...
# 9673  Competitive ice skater Tonya Harding rises amo...
# 9674  Plot: Bwakaw is a drama-comedy about growing o...
# ...
